# %%
import numpy as np
import pandas as pd
import random
from plotnine import *

# %% [markdown]
# # Generate switch data

# %%
X = list(range(0, 1010, 10))
X = [i/1000 for i in X]
data = []

t = 0.3 # Threshold for switch
for i in X:
    if i <= t:
        data.append([i, random.randint(90, 100)/100, "Excited"])
    else:
        data.append([i, random.randint(0, 10)/100, "Not Excited"])
df = pd.DataFrame(data)
df.columns = ["X", "Y", "SwitchState"]
# Radomly choose only top 81 elements in the data => to depict real data
df = df.sample(frac=1)
df = df[:81]
df.head()
# Out:
#         X     Y  SwitchState
# 33   0.33  0.10  Not Excited
# 20   0.20  0.99      Excited
# 66   0.66  0.06  Not Excited
# 100  1.00  0.00  Not Excited
# 8    0.08  0.98      Excited

# %%
ggplot(df, aes(x="X", y="Y", color="SwitchState"))+\
geom_point()+\
labs(title="Switch input and output graph", x="Input current", y="Output current")
# Out:
# <ggplot: (323048789)>
